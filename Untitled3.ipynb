# %% [markdown]
# <a href="https://colab.research.google.com/github/as-1212/ASD_Detection_Jetson/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b940dbee-ee1e-48f9-a299-4cc4bb020281" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b940dbee-ee1e-48f9-a299-4cc4bb020281">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d navdeepjakhar/asd-eye-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/navdeepjakhar/asd-eye-data
# License(s): unknown
# ...
# 100% 9.42M/9.42M [00:00<00:00, 63.1MB/s]

# %%
import zipfile

with zipfile.ZipFile('asd-eye-data.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/dataset')

# %%
import os
os.listdir('/content/dataset')
# Out:
# ['ASDeyedata']

# %%
import os
os.listdir('/content/dataset')
# Out:
# ['ASDeyedata']

# %%
import os
os.listdir('/content/dataset/ASDeyedata')
# Out:
# ['TCImages-0', 'TSImages-1']

# %%
base_path = '/content/dataset/ASDeyedata'

# %%
import os
import shutil
import random

base_path = '/content/dataset/ASDeyedata'
train_path = '/content/data/train'
test_path = '/content/data/test'

# Map real folder names → model class names
class_map = {
    'TSImages-1': 'autism',
    'TCImages-0': 'non_autism'
}

for original, new in class_map.items():
    os.makedirs(f"{train_path}/{new}", exist_ok=True)
    os.makedirs(f"{test_path}/{new}", exist_ok=True)

    files = os.listdir(f"{base_path}/{original}")
    random.shuffle(files)

    split = int(0.8 * len(files))

    train_files = files[:split]
    test_files = files[split:]

    for f in train_files:
        shutil.copy(f"{base_path}/{original}/{f}", f"{train_path}/{new}/{f}")

    for f in test_files:
        shutil.copy(f"{base_path}/{original}/{f}", f"{test_path}/{new}/{f}")

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2

# %%
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

test_gen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_gen.flow_from_directory(
    '/content/data/train',   # ✅ after your split
    target_size=(224,224),
    batch_size=32,
    class_mode='binary'
)

test_data = test_gen.flow_from_directory(
    '/content/data/test',
    target_size=(224,224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 437 images belonging to 3 classes.
# Found 110 images belonging to 3 classes.

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# Freeze layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.3730 - loss: -13.8644 - val_accuracy: 0.4000 - val_loss: -32.5836
# Epoch 2/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 636ms/step - accuracy: 0.4005 - loss: -49.1358 - val_accuracy: 0.4000 - val_loss: -77.2633
# Epoch 3/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 528ms/step - accuracy: 0.4005 - loss: -96.3510 - val_accuracy: 0.4000 - val_loss: -137.8802
# Epoch 4/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 645ms/step - accuracy: 0.4005 - loss: -160.9219 - val_accuracy: 0.4000 - val_loss: -214.8716
# Epoch 5/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 658ms/step - accuracy: 0.4005 - loss: -241.5151 - val_accuracy: 0.4000 - val_loss: -310.2754
# Epoch 6/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 548ms/step - accuracy: 0.4005 - loss: -339.6989 - val_accuracy: 0.4000 - val_loss: -426.1957
# Epoch 7/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 635ms/step - accuracy: 0.4005 - loss: -457.3174 - val_accuracy: 0.4000 - val_loss: -560.2344
# Epoch 8/10
# ...

# %%
loss, acc = model.evaluate(test_data)
print("Final Accuracy:", acc)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.4000 - loss: -1102.7627
# Final Accuracy: 0.4000000059604645

# %%
model.save("autism_eye_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download("autism_eye_model.h5")

# %%
print(train_data.class_indices)
# Out:
# {'Autistic': 0, 'autism': 1, 'non_autism': 2}

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(patience=3, restore_best_weights=True)

history = model.fit(
    train_data,
    validation_data=test_data,
    epochs=15,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 655ms/step - accuracy: 0.4005 - loss: -1128.3586 - val_accuracy: 0.4000 - val_loss: -1324.6484
# Epoch 2/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 534ms/step - accuracy: 0.4005 - loss: -1359.1895 - val_accuracy: 0.4000 - val_loss: -1573.2023
# Epoch 3/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 597ms/step - accuracy: 0.4005 - loss: -1596.1432 - val_accuracy: 0.4000 - val_loss: -1842.1122
# Epoch 4/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 615ms/step - accuracy: 0.4005 - loss: -1846.3236 - val_accuracy: 0.4000 - val_loss: -2137.1455
# Epoch 5/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 536ms/step - accuracy: 0.4005 - loss: -2135.4714 - val_accuracy: 0.4000 - val_loss: -2449.0330
# Epoch 6/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 626ms/step - accuracy: 0.4005 - loss: -2439.1580 - val_accuracy: 0.4000 - val_loss: -2785.5154
# Epoch 7/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 644ms/step - accuracy: 0.4005 - loss: -2734.1970 - val_accuracy: 0.4000 - val_loss: -3146.9937
# Epoch 8/15
# ...

# %%
loss, acc = model.evaluate(test_data)
print("Final Accuracy:", acc)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.4000 - loss: -6840.5249
# Final Accuracy: 0.4000000059604645

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt

# %%
y_pred = model.predict(test_data)
y_pred = (y_pred > 0.5).astype(int)  # convert to 0/1
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step

# %%
y_true = test_data.classes

# %%
cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[44  0]
#  [66  0]]

# %%
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.colorbar()

labels = ['Non-Autism', 'Autism']
plt.xticks([0,1], labels)
plt.yticks([0,1], labels)

plt.xlabel("Predicted")
plt.ylabel("Actual")

for i in range(2):
    for j in range(2):
        plt.text(j, i, cm[i, j], ha='center', va='center')

plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=['Non-Autism', 'Autism']))
# Out:
#               precision    recall  f1-score   support
#
#   Non-Autism       0.40      1.00      0.57        44
#       Autism       0.00      0.00      0.00        66
#
#     accuracy                           0.40       110
#    macro avg       0.20      0.50      0.29       110
# weighted avg       0.16      0.40      0.23       110
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
test_data.reset()

y_pred = model.predict(test_data)
y_pred = (y_pred > 0.5).astype(int)
y_true = test_data.classes
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# %%
test_data.reset()

# %%
y_pred_probs = model.predict(test_data)
y_pred = (y_pred_probs > 0.5).astype(int).reshape(-1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step

# %%
y_true = test_data.classes

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.40      1.00      0.57        44
#            2       0.00      0.00      0.00        66
#
#     accuracy                           0.40       110
#    macro avg       0.20      0.50      0.29       110
# weighted avg       0.16      0.40      0.23       110
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[44  0]
#  [66  0]]

# %%
plt.figure()

plt.imshow(cm)
plt.title("Confusion Matrix")
plt.colorbar()

labels = ['Non-Autism', 'Autism']
plt.xticks([0,1], labels)
plt.yticks([0,1], labels)

plt.xlabel("Predicted")
plt.ylabel("Actual")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha='center', va='center')

plt.show()

# %%
accuracy = np.sum(y_pred == y_true) / len(y_true)
print("Manual Accuracy:", accuracy)
# Out:
# Manual Accuracy: 0.4

# %%
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    zoom_range=0.3,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8,1.2]
)

# %%
from tensorflow.keras.layers import Dropout

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
class_weight = {0:1, 1:1.5}

model.fit(
    train_data,
    validation_data=test_data,
    epochs=15,
    class_weight=class_weight,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 894ms/step - accuracy: 0.4005 - loss: -6635.8276 - val_accuracy: 0.4000 - val_loss: -7395.9092
# Epoch 2/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 526ms/step - accuracy: 0.4005 - loss: -7172.7046 - val_accuracy: 0.4000 - val_loss: -7970.9468
# Epoch 3/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 761ms/step - accuracy: 0.4005 - loss: -7754.3613 - val_accuracy: 0.4000 - val_loss: -8576.9639
# Epoch 4/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 769ms/step - accuracy: 0.4005 - loss: -8294.5977 - val_accuracy: 0.4000 - val_loss: -9215.1357
# Epoch 5/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 712ms/step - accuracy: 0.4005 - loss: -8879.5312 - val_accuracy: 0.4000 - val_loss: -9863.1719
# Epoch 6/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 544ms/step - accuracy: 0.4005 - loss: -9489.4941 - val_accuracy: 0.4000 - val_loss: -10528.9355
# Epoch 7/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 679ms/step - accuracy: 0.4005 - loss: -10092.6133 - val_accuracy: 0.4000 - val_loss: -11215.1611
# ...

# %%
for layer in base_model.layers[-30:]:
    layer.trainable = True

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
from tensorflow.keras.regularizers import l2

x = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)

# %%
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[44  0]
#  [66  0]]

# %%
plt.figure()

plt.imshow(cm)
plt.title("Confusion Matrix")
plt.colorbar()

labels = ['Non-Autism', 'Autism']
plt.xticks([0,1], labels)
plt.yticks([0,1], labels)

plt.xlabel("Predicted")
plt.ylabel("Actual")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha='center', va='center')

plt.show()

# %%
print(classification_report(
    y_true,
    y_pred,
    target_names=['Non-Autism', 'Autism']
))
# Out:
#               precision    recall  f1-score   support
#
#   Non-Autism       0.40      1.00      0.57        44
#       Autism       0.00      0.00      0.00        66
#
#     accuracy                           0.40       110
#    macro avg       0.20      0.50      0.29       110
# weighted avg       0.16      0.40      0.23       110
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
